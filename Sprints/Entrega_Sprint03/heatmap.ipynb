# %% [markdown]
# ### Instalando bibliotecas ###

# %%
# !pip install pandas matplotlib seaborn opencv-python

import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import cv2 #opencv

# %% [markdown]
# #### Lendo o CSV (Planilha)  ###

# %%
df = pd.read_csv("clicks.csv")
df.sample(3)
# Out:
#                    Timestamp  X Position  Y Position
# 74  2024-03-22T14:01:16.504Z         602        3349
# 73  2024-03-22T14:01:16.312Z         602        3349
# 31  2024-03-22T14:01:04.285Z         322        1472

# %% [markdown]
# criando grafico

# %%
sns.scatterplot(
    df,
    x = "X Position",
    y = "Y Position",
    c = "k"
)
# Out:
# <Axes: xlabel='X Position', ylabel='Y Position'>

# %% [markdown]
# Criando o Heatmap e alterando algumas coordenadas para que fique alinhado

# %%
image = cv2.imread('fundo.jpeg')

#corrigindo imagem para o rgb
image = cv2.cvtColor (image, cv2.COLOR_BGR2RGB)
         

plt.imshow(image)
df_escalado = df.copy()

df_escalado['X Position'] = df_escalado['X Position'] / 1.1
df_escalado['Y Position'] = df_escalado['Y Position'] / 0.9

sns.scatterplot(
    df_escalado,
    x = "X Position",
    y = "Y Position",
    c = "k", s=1
)

sns.kdeplot(
    df_escalado,
        x = "X Position",
        y = "Y Position",
        lw= 0.01, fill=True, alpha=.75, cmap='rocket'
)

#limitando tamanho das linhas
plt.xlim(0,image.shape[1])
plt.ylim(image.shape[0], 0)


plt.axis("off")
plt.tight_layout()
plt.savefig("heatmap.png", dpi = 1200)
plt.show()
# Out:
# c:\ProgramData\anaconda3\lib\site-packages\seaborn\distributions.py:1176: UserWarning: The following kwargs were not used by contour: 'lw'
#   cset = contour_func(
