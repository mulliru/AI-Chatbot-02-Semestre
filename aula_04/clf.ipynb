# %%
# !pip install pandas matplotlib seaborn

import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("dados_flu.csv") #le a tabela csv

df.sample(5) #da 5 dados aleatorios
# Out:
#        id_do_respondente  preocupação_com_h1n1  conhecimento_sobre_h1n1  \
# 14691              14691                   2.0                      2.0
# 14439              14439                   1.0                      2.0
# 8712                8712                   1.0                      1.0
# 23467              23467                   0.0                      0.0
# 19602              19602                   0.0                      2.0
#
#        comportamento_medicamentos_antivirais  comportamento_evitamento  \
# 14691                                    0.0                       1.0
# 14439                                    0.0                       1.0
# 8712                                     0.0                       1.0
# 23467                                    0.0                       0.0
# 19602                                    0.0                       1.0
#
#        comportamento_uso_de_máscara_facial  comportamento_lavagem_das_mãos  \
# ...

# %%
df.isnull() # Retorna um DataFrame com valores booleanos: True para valores NaN (ausentes) e False para valores não NaN (presentes)
# Out:
#        id_do_respondente  preocupação_com_h1n1  conhecimento_sobre_h1n1  \
# 0                  False                 False                    False
# 1                  False                 False                    False
# 2                  False                 False                    False
# 3                  False                 False                    False
# 4                  False                 False                    False
# ...                  ...                   ...                      ...
# 26702              False                 False                    False
# 26703              False                 False                    False
# 26704              False                 False                    False
# 26705              False                 False                    False
# 26706              False                 False                    False
#
#        comportamento_medicamentos_antivirais  comportamento_evitamento  \
# ...

# %%
df.isnull().sum() #resumo dos dados faltantes
# Out:
# id_do_respondente                                    0
# preocupação_com_h1n1                                92
# conhecimento_sobre_h1n1                            116
# comportamento_medicamentos_antivirais               71
# comportamento_evitamento                           208
# comportamento_uso_de_máscara_facial                 19
# comportamento_lavagem_das_mãos                      42
# comportamento_reuniões_grandes                      87
# comportamento_saída_de_casa                         82
# comportamento_toque_na_face                        128
# recomendação_médica_h1n1                          2160
# recomendação_médica_sazonal                       2160
# condição_médica_crônica                            971
# criança_menor_de_6_meses                           820
# trabalhador_de_saúde                               804
# seguro_de_saúde                                  12274
# opinião_sobre_a_efetividade_da_vacina_h1n1         391
# ...

# %%
df = df.drop(["seguro_de_saude","seguro_de_saude.1", "industria_de_emprego", "ocupação"], axis=1)

# %%
plt.figure(figsize=(19,19))
sns.heatmap(df.corr(), annot=True,
            cmap="coolwarm", center=0)
# Out:
# C:\Users\logonrmlocal\AppData\Local\Temp\ipykernel_14232\1568506123.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True,
# <Axes: >

# %%
df.columns #paara imprimir as colunas que tem no csv
# Out:
# Index(['id_do_respondente', 'preocupação_com_h1n1', 'conhecimento_sobre_h1n1',
#        'comportamento_medicamentos_antivirais', 'comportamento_evitamento',
#        'comportamento_uso_de_máscara_facial', 'comportamento_lavagem_das_mãos',
#        'comportamento_reuniões_grandes', 'comportamento_saída_de_casa',
#        'comportamento_toque_na_face', 'recomendação_médica_h1n1',
#        'recomendação_médica_sazonal', 'condição_médica_crônica',
#        'criança_menor_de_6_meses', 'trabalhador_de_saúde', 'seguro_de_saúde',
#        'opinião_sobre_a_efetividade_da_vacina_h1n1',
#        'opinião_sobre_o_risco_h1n1',
#        'opinião_sobre_a_doença_por_vacinação_h1n1',
#        'opinião_sobre_a_efetividade_da_vacina_sazonal',
#        'opinião_sobre_o_risco_sazonal',
#        'opinião_sobre_a_doença_por_vacinação_sazonal',
#        'adultos_no_agregado_familiar', 'crianças_no_agregado_familiar',
#        'vacina_h1n1', 'vacina_sazonal', 'seguro_de_saúde.1',
# ...

# %%
x = df[ ["conhecimento_sobre_h1n1",
        "crianças_no_agregado_familiar",
        "opinião_sobre_a_doença_por_vacinação_h1n1"


]]

y = df["vacina_sazonal"]

# %%
# !pip install scikit-learn

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
clf = DecisionTreeClassifier(max_depth=3)

# %%
clf.fit(x, y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
plt.figure(figsize=(20,10))
plot_tree(clf, fontsize=12);
